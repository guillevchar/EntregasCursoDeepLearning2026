# %% [markdown]
# <a href="https://colab.research.google.com/github/guillevchar/EntregasCursoDeepLearning2026/blob/main/PRACTICA_03_GuillermoVicenteCharco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Guillermo Vicente Charco guivicen@ucm.es

# %% [markdown]
# <font color="darkorange" size="10"><b>03. Regresión con MLP</b></font>
#
# Miguel A. Castellanos

# %% [markdown]
# En este cuaderno vamos a construir nuestras primeras redes neuronales usando **pytorch**, vete fijándote en el código y en las explicaciones que se adjuntan porque la mayoría del código se puede reutilizar, de hecho, un buen consejo es preparar tu propio **"*manual*"** con las partes de código y explicaciones que creas relevantes.
#
# Vamos a empezar por las redes más sencillas, los __perceptrones multicapa__, exactamente iguales que los que hemos estado utilizando en [playground](https://playground.tensorflow.org/).
#
# La tarea es identica a la realizada en playground, **predecir unos valores cuantitativos**, pero ahora en vez de ser un sandbox completamente opaco vamos a programar nuestras redes en tiempo real con todo el control.
#
# __No te frustres__, a veces escribir código es frustrante porque te da la sensación de que unas veces funciona y otras no. Los ordenadores son deterministas, no tienen opiniones ni les caes mal; si antes te ha funcionado y ahora no es porque hay algo diferente, sigue intentándolo y si ves que no lo consigues consulta con un compañero o con el profesor.
#
# En general, los ejercicios siempre están basados en cosas que han sido explicadas en clase, cuando haya un ejercicio que no te salga, relee los materiales y fíjate despacio en el código previo, es posible que la solución la tengas a la vista. Si aún así no encuentras la solución pregunta a tus compañeros y __no dudes en contactar conmigo__.

# %% [markdown]
# Lo primero que vamos a hacer es cargar un montón de paquetes y librerías de python que vamos a necesitar para que se calculen las redes. No te preocupes por esta parte, no es necesario entender qué o cómo lo hace, simplemente ejecútala. Lo que hace este código es:
#
# Carga los paquetes: numpy, tensorflow2, panda, matplolib, pytorch y sklearn. Son paquetes básicos para el trabajo con datos y los paquetes relacionados con Deep Learning.
# Para ejecutar un código puedes pinchar en la flecha de la celda o usar Ctr+Enter en el teclado.

# %% [markdown]
# ## Empezamos trabajando con los datos

# %%
# Importamos las librerias que vamos a necesitar

import numpy as np
import matplotlib.pyplot as plt
import sklearn
import torch

# %%
# Generamos unos datos de X e y usando numpy

X = np.array(
    [258.0, 270.0, 294.0, 320.0, 342.0, 368.0, 396.0, 446.0, 480.0, 586.0]
)[:, np.newaxis]

y = np.array(
    [236.4, 234.4, 252.8, 298.6, 314.2, 342.2, 360.8, 368.0, 391.2, 390.8]
)

# %% [markdown]
# Un consejo, las nomenclaturas de las variables son libres, pero se recomienda que sean coherentes, por ejemplo, a veces se les llama X (en mayúscula) e y, otras veces features and labels (o targets).
#
# Lo que te recomiendo es que elijas la tuya y escribas tu código siendo coherente con ella, luego cuando tengas que buscar ***bugs*** y errores te harás menos lío.
#
# Yo voy a usar X e y en esta práctica.

# %%
# Comprobamos que se han creado bien

print(X)
print(y)
# Out:
# [[258.]
#  [270.]
#  [294.]
#  [320.]
#  [342.]
#  [368.]
#  [396.]
#  [446.]
#  [480.]
#  [586.]]
# [236.4 234.4 252.8 298.6 314.2 342.2 360.8 368.  391.2 390.8]

# %% [markdown]
# Fíjate que y es un vector pero X es una matriz de 10 filas y una columna.

# %%
# Ploteamos X e y

plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
# Vamos a utilizar la funcion LinearRegression del paquete sklearn para calcular la recta a esos puntos

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X, y)

# create predictions for plotting
X_range = np.arange(250, 600, 10)[:, np.newaxis] # de nuevo creamos una matrix nx1 en vez de un vector
y_linear = lr.predict(X_range)

# %%
# Dibujamos tanto los puntos como la recta

plt.scatter(X, y, label="Datos")
plt.plot(X_range, y_linear, label="Regresión Lineal", linestyle="--", color="orange")
plt.legend()
plt.show()

# %% [markdown]
# Ya tenemos los datos y la predicción que se puede hacer con una recta de regresión, ahora vamos a construir una MLP para ver cómo mejoramos la predicción.

# %% [markdown]
# ## Vamos a preparar los datos
#
# - Lo primero es hacer la normalización de X e y
# - Luego se crea un dataset formado por tensores y que sea iterable
#
# **Respecto a la normalización:**
#
# - En Keras la estrategia es normalizar X y dejar y en su escala, poniendo una función de activación lineal que reescale desde los pesos de la red a la escala original de y
# - En pytorch no se recomienda, se elimina esa última capa y se deja en la misma escala que los pesos. Posteriormente, cuando se termina de entrenar, se devuelven las predicciones a la misma escala
#
# **Respecto a la construcción del dataset:**
#
# - Ahora viene una parte extraña, como pytorch tiene que usar tensores y nosotros hemos creados los datos usando numpy hay que convertirlos. Para ello se usa la funcion ***TensorDataset***
# - Además, es necesario hacer que nuestros datos sean iterables, es decir, que puedan utilizarse uno a uno por la red para entrenarla, esto se hace con la función ***DataLoader***
#
# Ambas funciones tienen su complejidad (manejar los datos es más complejo que estimar la red) y poco a poco aprenderemos a sacarles más provecho.

# %%
# preparamos los datos

from torch.utils.data import TensorDataset, DataLoader

# Normalizamos X e y
x_mean, x_std = X.mean(), X.std()
y_mean, y_std = y.mean(), y.std()

X_norm = (X - x_mean) / x_std
y_norm = (y - y_mean) / y_std

# Pasamos las variables a tensores
tensor_X = torch.Tensor(X_norm) # transform to torch tensor
tensor_y = torch.Tensor(y_norm)

# Creamos el dataset y el dataloader
my_dataset = TensorDataset(tensor_X,tensor_y) # create your datset
my_dataloader = DataLoader(my_dataset) # create your dataloader

# %% [markdown]
# ## Ahora vamos a definir la red
#
# Es una red cutrecilla
#
# Definimos la red como una clase, es lo recomendado
# vamos a crear una red con:
# - Una entrada con las dimensiones de X
# - Una única capa con una neurona
# - Una de salida con una unica neurona sin activación

# %%
# Definimos la red como una clase, es lo recomendado
# vamos a crear una red con:
#   - Una entrada con las dimensiones de X
#   - Una capa oculta de 1 neurona
#   - Una de salida con una unica neurona sin activación


class MLP(torch.nn.Module):
    def __init__(self, X_nvars):
        super().__init__()

        self.layers = torch.nn.Sequential(

            # Hidden Layer 1
            torch.nn.Linear(X_nvars, 1), # Hacemos el sumatorio
            torch.nn.ReLU(),              # Aplicamos la función de activacion

            # output layer
            torch.nn.Linear(1, 1),
        )

    def forward(self, x):
        output = self.layers(x)
        return output

# %% [markdown]
# ## Creamos la red y definimos los Hiper-parámetros

# %%
# Fijamos la semilla a un valor para que los resultados sean identicos
torch.manual_seed(1)

# Ahora fijamos algunos hiper-parámetros

# Creamos el modelo MLP
model = MLP(X_nvars=1)

# Definimos la función loss
loss_fn = torch.nn.MSELoss()

# Elegimos el optimizador
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# ## Ahora hacemos el entrenamiento de la red

# %%
import torch.nn.functional as F

# Fijamos el número de épocas o iteraciones
num_epochs = 200

# Una variables donde vamos a ir guardando los valores del loss para ploterarlos
loss_history = []

for epoch in range(num_epochs):
    model = model.train() # se fijan algunas cosas para hacer entrenamiento

    # En esta parte se define el batch
    # No te preocupes que aún no sabemos qué es
    # MUY IMPORTANTE, nunca uses el mismo nombre que tus datos o los sobreescribe
    for batch_idx, (features, targets) in enumerate(my_dataloader):

        output = model(features)            # Hacemos el forward
        loss = loss_fn(output, targets)     # Calculamos el loss

        optimizer.zero_grad()        # Ponemos a cero el gradiente
        loss.backward()              # Calculamos los gradientes (la derivada del loss)
        optimizer.step()             # Cambiamos los pesos de la red

        # Cada cierto tiempo vamos a imprimir un poco de información
        # para saber qué está pasando
        if not batch_idx % 100:
            print(
                f"Epoch: {epoch+1:03d}/{num_epochs:03d}"
                # f" | Batch {batch_idx:03d}/{len(train_loader):03d}"
                f" | Batch {batch_idx:03d}/{len(my_dataloader):03d}"
                f" | Train Loss: {loss.item():.2f}"
            )
        # añadimos el loss a loss_history
    loss_history.append(loss.item())
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: 001/200 | Batch 000/010 | Train Loss: 3.56
# Epoch: 002/200 | Batch 000/010 | Train Loss: 3.97
# Epoch: 003/200 | Batch 000/010 | Train Loss: 3.95
# Epoch: 004/200 | Batch 000/010 | Train Loss: 3.93
# Epoch: 005/200 | Batch 000/010 | Train Loss: 3.92
# Epoch: 006/200 | Batch 000/010 | Train Loss: 3.91
# Epoch: 007/200 | Batch 000/010 | Train Loss: 3.89
# Epoch: 008/200 | Batch 000/010 | Train Loss: 3.85
# Epoch: 009/200 | Batch 000/010 | Train Loss: 3.74
# Epoch: 010/200 | Batch 000/010 | Train Loss: 3.33
# Epoch: 011/200 | Batch 000/010 | Train Loss: 2.60
# Epoch: 012/200 | Batch 000/010 | Train Loss: 2.14
# Epoch: 013/200 | Batch 000/010 | Train Loss: 2.05
# Epoch: 014/200 | Batch 000/010 | Train Loss: 1.78
# Epoch: 015/200 | Batch 000/010 | Train Loss: 1.52
# Epoch: 016/200 | Batch 000/010 | Train Loss: 1.53
# Epoch: 017/200 | Batch 000/010 | Train Loss: 1.35
# Epoch: 018/200 | Batch 000/010 | Train Loss: 1.42
# Epoch: 019/200 | Batch 000/010 | Train Loss: 1.24
# Epoch: 020/200 | Batch 000/010 | Train Loss: 1.24
# Epoch: 021/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 022/200 | Batch 000/010 | Train Loss: 1.27
# Epoch: 023/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 024/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 025/200 | Batch 000/010 | Train Loss: 1.38
# Epoch: 026/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 027/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 028/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 029/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 030/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 031/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 032/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 033/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 034/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 035/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 036/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 037/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 038/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 039/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 040/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 041/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 042/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 043/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 044/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 045/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 046/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 047/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 048/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 049/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 050/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 051/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 052/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 053/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 054/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 055/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 056/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 057/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 058/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 059/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 060/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 061/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 062/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 063/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 064/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 065/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 066/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 067/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 068/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 069/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 070/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 071/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 072/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 073/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 074/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 075/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 076/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 077/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 078/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 079/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 080/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 081/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 082/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 083/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 084/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 085/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 086/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 087/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 088/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 089/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 090/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 091/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 092/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 093/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 094/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 095/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 096/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 097/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 098/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 099/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 100/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 101/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 102/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 103/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 104/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 105/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 106/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 107/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 108/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 109/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 110/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 111/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 112/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 113/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 114/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 115/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 116/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 117/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 118/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 119/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 120/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 121/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 122/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 123/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 124/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 125/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 126/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 127/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 128/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 129/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 130/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 131/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 132/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 133/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 134/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 135/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 136/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 137/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 138/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 139/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 140/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 141/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 142/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 143/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 144/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 145/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 146/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 147/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 148/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 149/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 150/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 151/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 152/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 153/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 154/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 155/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 156/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 157/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 158/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 159/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 160/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 161/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 162/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 163/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 164/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 165/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 166/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 167/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 168/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 169/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 170/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 171/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 172/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 173/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 174/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 175/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 176/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 177/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 178/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 179/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 180/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 181/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 182/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 183/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 184/200 | Batch 000/010 | Train Loss: 1.20
# Epoch: 185/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 186/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 187/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 188/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 189/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 190/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 191/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 192/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 193/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 194/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 195/200 | Batch 000/010 | Train Loss: 1.37
# Epoch: 196/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 197/200 | Batch 000/010 | Train Loss: 1.23
# Epoch: 198/200 | Batch 000/010 | Train Loss: 1.22
# Epoch: 199/200 | Batch 000/010 | Train Loss: 1.21
# Epoch: 200/200 | Batch 000/010 | Train Loss: 1.20

# %%
# Vamos a hacer un plot del loss, a ver qué ha pasado

plt.plot(loss_history)

# %%
# Vamos a evaluar el funcionamiento del modelo

model.eval() # se fijan parametros del modelo para evaluar

# predecimos los valores del rango X_range segun el MLP

# Se pasan a un tensor normalizado
X_range_norm = (X_range - x_mean) / x_std
X_range_norm = torch.tensor(X_range_norm, dtype=torch.float32)

# Se meten en el modelo
y_mlp_norm = model(X_range_norm)

# Ahora se desnormalizan para que estén en la misma escala
y_mlp_norm = y_mlp_norm.detach().numpy().astype(np.float64) # dejan de ser un tensor
y_mlp = y_mlp_norm * y_std + y_mean # desnormalizan

# %%
# Vamos a hacer un plot con los resultados

# Los datos originales
plt.scatter(X, y, label="Datos")

# Los datos predichos por la regresion lineal
plt.plot(X_range, y_linear, label="Regresión lineal", linestyle="--", color='green')

# Los datos predichos por el MLP
plt.plot(X_range, y_mlp, label="MLP", color='orange')

plt.xlabel("X")
plt.ylabel("y")
plt.legend()

plt.show()

# %% [markdown]
# ---
# # Ejercicios
#
# Crea un notebook de colab con las soluciones a los ejercicios, hazlo público y sube el enlace al campus virtual

# %% [markdown]
# ### 01. Ejercicio 1
#
# Con los datos de este ejemplo crea una red neuronal que sea capaz de generar un error de cero (es decir, la linea de MLP atraviesa todos los puntos).

# %%
# Como los datos y los paquetes utilizados están arriba, es necesario ejecutar
# el código de arriba proporcionado.

# Clase con el modelo
class MLP1(torch.nn.Module):
    def __init__(self, X_nvars):
        super().__init__()

        self.layers = torch.nn.Sequential(

            #  Hidden Layer 1
            torch.nn.Linear(X_nvars, 100),
            torch.nn.ReLU(),

            #  Hidden Layer 2
            torch.nn.Linear(100, 1),
            torch.nn.Tanh(),

            # output layer
            torch.nn.Linear(1, 1),
        )

    def forward(self, x):
        output = self.layers(x)
        return output

# Fijamos la semilla
torch.manual_seed(1)

# Creamos el modelo MLP
model = MLP1(X_nvars=1)

# Definimos la función loss
loss_fn = torch.nn.MSELoss()

# Elegimos el optimizador
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# Fijamos el número de épocas o iteraciones
num_epochs = 500

# Una variables donde vamos a ir guardando los valores del loss para ploterarlos
loss_history = []

for epoch in range(num_epochs):
    model = model.train() # se fijan algunas cosas para hacer entrenamiento

    for batch_idx, (features, targets) in enumerate(my_dataloader):

        output = model(features)
        loss = loss_fn(output, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if not batch_idx % 100:
            print(
                f"Epoch: {epoch+1:03d}/{num_epochs:03d}"
                f" | Batch {batch_idx:03d}/{len(my_dataloader):03d}"
                f" | Train Loss: {loss.item():.2f}"
            )

        # añadimos el loss a loss_history
    loss_history.append(loss.item())

plt.plot(loss_history)
# Out:
# Epoch: 001/500 | Batch 000/010 | Train Loss: 4.31
# Epoch: 002/500 | Batch 000/010 | Train Loss: 3.37
# Epoch: 003/500 | Batch 000/010 | Train Loss: 1.43
# Epoch: 004/500 | Batch 000/010 | Train Loss: 0.43
# Epoch: 005/500 | Batch 000/010 | Train Loss: 0.55
# Epoch: 006/500 | Batch 000/010 | Train Loss: 0.06
# Epoch: 007/500 | Batch 000/010 | Train Loss: 0.06
# Epoch: 008/500 | Batch 000/010 | Train Loss: 0.04
# Epoch: 009/500 | Batch 000/010 | Train Loss: 0.03
# Epoch: 010/500 | Batch 000/010 | Train Loss: 0.15
# Epoch: 011/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 012/500 | Batch 000/010 | Train Loss: 0.20
# Epoch: 013/500 | Batch 000/010 | Train Loss: 0.02
# Epoch: 014/500 | Batch 000/010 | Train Loss: 0.06
# Epoch: 015/500 | Batch 000/010 | Train Loss: 0.07
# Epoch: 016/500 | Batch 000/010 | Train Loss: 0.08
# Epoch: 017/500 | Batch 000/010 | Train Loss: 0.05
# Epoch: 018/500 | Batch 000/010 | Train Loss: 0.04
# Epoch: 019/500 | Batch 000/010 | Train Loss: 0.03
# Epoch: 020/500 | Batch 000/010 | Train Loss: 0.03
# Epoch: 021/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 022/500 | Batch 000/010 | Train Loss: 0.02
# Epoch: 023/500 | Batch 000/010 | Train Loss: 0.04
# Epoch: 024/500 | Batch 000/010 | Train Loss: 0.06
# Epoch: 025/500 | Batch 000/010 | Train Loss: 0.04
# Epoch: 026/500 | Batch 000/010 | Train Loss: 0.03
# Epoch: 027/500 | Batch 000/010 | Train Loss: 0.02
# Epoch: 028/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 029/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 030/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 031/500 | Batch 000/010 | Train Loss: 0.03
# Epoch: 032/500 | Batch 000/010 | Train Loss: 0.04
# Epoch: 033/500 | Batch 000/010 | Train Loss: 0.03
# Epoch: 034/500 | Batch 000/010 | Train Loss: 0.02
# Epoch: 035/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 036/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 037/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 038/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 039/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 040/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 041/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 042/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 043/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 044/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 045/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 046/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 047/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 048/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 049/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 050/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 051/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 052/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 053/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 054/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 055/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 056/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 057/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 058/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 059/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 060/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 061/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 062/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 063/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 064/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 065/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 066/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 067/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 068/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 069/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 070/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 071/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 072/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 073/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 074/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 075/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 076/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 077/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 078/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 079/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 080/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 081/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 082/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 083/500 | Batch 000/010 | Train Loss: 0.01
# Epoch: 084/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 085/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 086/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 087/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 088/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 089/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 090/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 091/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 092/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 093/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 094/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 095/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 096/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 097/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 098/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 099/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 100/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 101/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 102/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 103/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 104/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 105/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 106/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 107/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 108/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 109/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 110/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 111/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 112/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 113/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 114/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 115/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 116/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 117/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 118/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 119/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 120/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 121/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 122/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 123/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 124/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 125/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 126/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 127/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 128/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 129/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 130/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 131/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 132/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 133/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 134/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 135/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 136/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 137/500 | Batch 000/010 | Train Loss: 0.00
# Epoch:
500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 499/500 | Batch 000/010 | Train Loss: 0.00
# Epoch: 500/500 | Batch 000/010 | Train Loss: 0.00

# %%
model.eval()

X_range_norm = (X_range - x_mean) / x_std
X_range_norm = torch.tensor(X_range_norm, dtype=torch.float32)

y_mlp_norm = model(X_range_norm)

y_mlp_norm = y_mlp_norm.detach().numpy().astype(np.float64)
y_mlp = y_mlp_norm * y_std + y_mean

# Vamos a hacer un plot con los resultados
# Los datos originales
plt.scatter(X, y, label="Datos")

# Los datos predichos por el MLP
plt.plot(X_range, y_mlp, label="MLP", color='orange')

plt.xlabel("X")
plt.ylabel("y")
plt.legend()

plt.show()

# %% [markdown]
# ### 02. Ejercicio 2
#
# Usando el código siguiente, construye un MLP que se ajuste razonablemente a los puntos de ese seno. Puedes jugar con la creación de datos.

# %%
# Creamos los datos, en este caso un seno

import numpy as np

cycles = 2  # numero de periodos
n = 100     # numero de datos en x

length = 2 * np.pi * cycles

x = np.arange(0, length, length / n)
y = np.sin(x)

plt.plot(x, y, '-')

print(x.shape)
print(y.shape)
# Out:
# (100,)
# (100,)

# %%
# Normalizamos x e y (de los datos del seno)
x_mean_sine, x_std_sine = x.mean(), x.std()
y_mean_sine, y_std_sine = y.mean(), y.std()

x_norm = (x - x_mean_sine) / x_std_sine
y_norm = (y - y_mean_sine) / y_std_sine

# Pasamos las variables a tensores
tensor_x = torch.Tensor(x_norm).unsqueeze(1)
tensor_y = torch.Tensor(y_norm).unsqueeze(1)

# Creamos el dataset y el dataloader
my_dataset = TensorDataset(tensor_x,tensor_y)
my_dataloader = DataLoader(my_dataset)

# %%
# Clase con el modelo
class MLP2(torch.nn.Module):
    def __init__(self, x_nvars):
        super().__init__()

        self.layers = torch.nn.Sequential(

            # Hidden Layer 1
            torch.nn.Linear(x_nvars, 20),
            torch.nn.ReLU(),

            # Hidden Layer 2
            torch.nn.Linear(20, 20),
            torch.nn.Sigmoid(),

            # Hidden Layer 3
            torch.nn.Linear(20, 1),
            torch.nn.Sigmoid(),


            # output layer
            torch.nn.Linear(1, 1),
        )

    def forward(self, x):
        output = self.layers(x)
        return output

# %%
# Fijamos la semilla
torch.manual_seed(1)

# Creamos el modelo MLP
model = MLP2(x_nvars=1)

# Definimos la función loss
loss_fn = torch.nn.MSELoss()

# Elegimos el optimizador
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# Fijamos el número de épocas o iteraciones
num_epochs = 500

# Una variables donde vamos a ir guardando los valores del loss para ploterarlos
loss_history = []

for epoch in range(num_epochs):
    model = model.train()

    for batch_idx, (features, targets) in enumerate(my_dataloader):

        output = model(features)
        loss = loss_fn(output, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if not batch_idx % 100:
            print(
                f"Epoch: {epoch+1:03d}/{num_epochs:03d}"

                f" | Batch {batch_idx:03d}/{len(my_dataloader):03d}"
                f" | Train Loss: {loss.item():.2f}"
            )

    # añadimos el loss a loss_history
    loss_history.append(loss.item())
# Out:
# Epoch: 001/500 | Batch 000/100 | Train Loss: 0.02
# Epoch: 002/500 | Batch 000/100 | Train Loss: 0.24
# Epoch: 003/500 | Batch 000/100 | Train Loss: 0.26
# Epoch: 004/500 | Batch 000/100 | Train Loss: 0.28
# Epoch: 005/500 | Batch 000/100 | Train Loss: 0.31
# Epoch: 006/500 | Batch 000/100 | Train Loss: 0.34
# Epoch: 007/500 | Batch 000/100 | Train Loss: 0.36
# Epoch: 008/500 | Batch 000/100 | Train Loss: 0.38
# Epoch: 009/500 | Batch 000/100 | Train Loss: 0.39
# Epoch: 010/500 | Batch 000/100 | Train Loss: 0.40
# Epoch: 011/500 | Batch 000/100 | Train Loss: 0.41
# Epoch: 012/500 | Batch 000/100 | Train Loss: 0.42
# Epoch: 013/500 | Batch 000/100 | Train Loss: 0.42
# Epoch: 014/500 | Batch 000/100 | Train Loss: 0.42
# Epoch: 015/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 016/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 017/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 018/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 019/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 020/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 021/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 022/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 023/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 024/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 025/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 026/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 027/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 028/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 029/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 030/500 | Batch 000/100 | Train Loss: 0.42
# Epoch: 031/500 | Batch 000/100 | Train Loss: 0.42
# Epoch: 032/500 | Batch 000/100 | Train Loss: 0.42
# Epoch: 033/500 | Batch 000/100 | Train Loss: 0.42
# Epoch: 034/500 | Batch 000/100 | Train Loss: 0.41
# Epoch: 035/500 | Batch 000/100 | Train Loss: 0.41
# Epoch: 036/500 | Batch 000/100 | Train Loss: 0.41
# Epoch: 037/500 | Batch 000/100 | Train Loss: 0.40
# Epoch: 038/500 | Batch 000/100 | Train Loss: 0.40
# Epoch: 039/500 | Batch 000/100 | Train Loss: 0.39
# Epoch: 040/500 | Batch 000/100 | Train Loss: 0.38
# Epoch: 041/500 | Batch 000/100 | Train Loss: 0.37
# Epoch: 042/500 | Batch 000/100 | Train Loss: 0.36
# Epoch: 043/500 | Batch 000/100 | Train Loss: 0.35
# Epoch: 044/500 | Batch 000/100 | Train Loss: 0.34
# Epoch: 045/500 | Batch 000/100 | Train Loss: 0.32
# Epoch: 046/500 | Batch 000/100 | Train Loss: 0.30
# Epoch: 047/500 | Batch 000/100 | Train Loss: 0.28
# Epoch: 048/500 | Batch 000/100 | Train Loss: 0.25
# Epoch: 049/500 | Batch 000/100 | Train Loss: 0.22
# Epoch: 050/500 | Batch 000/100 | Train Loss: 0.19
# Epoch: 051/500 | Batch 000/100 | Train Loss: 0.16
# Epoch: 052/500 | Batch 000/100 | Train Loss: 0.13
# Epoch: 053/500 | Batch 000/100 | Train Loss: 0.10
# Epoch: 054/500 | Batch 000/100 | Train Loss: 0.07
# Epoch: 055/500 | Batch 000/100 | Train Loss: 0.04
# Epoch: 056/500 | Batch 000/100 | Train Loss: 0.02
# Epoch: 057/500 | Batch 000/100 | Train Loss: 0.01
# Epoch: 058/500 | Batch 000/100 | Train Loss: 0.00
# Epoch: 059/500 | Batch 000/100 | Train Loss: 0.00
# Epoch: 060/500 | Batch 000/100 | Train Loss: 0.01
# Epoch: 061/500 | Batch 000/100 | Train Loss: 0.02
# Epoch: 062/500 | Batch 000/100 | Train Loss: 0.04
# Epoch: 063/500 | Batch 000/100 | Train Loss: 0.07
# Epoch: 064/500 | Batch 000/100 | Train Loss: 0.12
# Epoch: 065/500 | Batch 000/100 | Train Loss: 0.17
# Epoch: 066/500 | Batch 000/100 | Train Loss: 0.24
# Epoch: 067/500 | Batch 000/100 | Train Loss: 0.33
# Epoch: 068/500 | Batch 000/100 | Train Loss: 0.43
# Epoch: 069/500 | Batch 000/100 | Train Loss: 0.55
# Epoch: 070/500 | Batch 000/100 | Train Loss: 0.68
# Epoch: 071/500 | Batch 000/100 | Train Loss: 0.82
# Epoch: 072/500 | Batch 000/100 | Train Loss: 0.98
# Epoch: 073/500 | Batch 000/100 | Train Loss: 1.12
# Epoch: 074/500 | Batch 000/100 | Train Loss: 1.28
# Epoch: 075/500 | Batch 000/100 | Train Loss: 1.41
# Epoch: 076/500 | Batch 000/100 | Train Loss: 1.55
# Epoch: 077/500 | Batch 000/100 | Train Loss: 1.65
# Epoch:
500 | Batch 000/100 | Train Loss: 1.51
# Epoch: 435/500 | Batch 000/100 | Train Loss: 1.77
# Epoch: 436/500 | Batch 000/100 | Train Loss: 1.44
# Epoch: 437/500 | Batch 000/100 | Train Loss: 1.68
# Epoch: 438/500 | Batch 000/100 | Train Loss: 1.59
# Epoch: 439/500 | Batch 000/100 | Train Loss: 1.72
# Epoch: 440/500 | Batch 000/100 | Train Loss: 1.53
# Epoch: 441/500 | Batch 000/100 | Train Loss: 1.83
# Epoch: 442/500 | Batch 000/100 | Train Loss: 1.39
# Epoch: 443/500 | Batch 000/100 | Train Loss: 1.59
# Epoch: 444/500 | Batch 000/100 | Train Loss: 1.75
# Epoch: 445/500 | Batch 000/100 | Train Loss: 1.51
# Epoch: 446/500 | Batch 000/100 | Train Loss: 1.80
# Epoch: 447/500 | Batch 000/100 | Train Loss: 1.56
# Epoch: 448/500 | Batch 000/100 | Train Loss: 1.75
# Epoch: 449/500 | Batch 000/100 | Train Loss: 1.50
# Epoch: 450/500 | Batch 000/100 | Train Loss: 1.76
# Epoch: 451/500 | Batch 000/100 | Train Loss: 1.51
# Epoch: 452/500 | Batch 000/100 | Train Loss: 1.79
# Epoch: 453/500 | Batch 000/100 | Train Loss: 1.42
# Epoch: 454/500 | Batch 000/100 | Train Loss: 1.60
# Epoch: 455/500 | Batch 000/100 | Train Loss: 1.77
# Epoch: 456/500 | Batch 000/100 | Train Loss: 1.44
# Epoch: 457/500 | Batch 000/100 | Train Loss: 1.64
# Epoch: 458/500 | Batch 000/100 | Train Loss: 1.79
# Epoch: 459/500 | Batch 000/100 | Train Loss: 1.44
# Epoch: 460/500 | Batch 000/100 | Train Loss: 1.62
# Epoch: 461/500 | Batch 000/100 | Train Loss: 1.81
# Epoch: 462/500 | Batch 000/100 | Train Loss: 1.44
# Epoch: 463/500 | Batch 000/100 | Train Loss: 1.62
# Epoch: 464/500 | Batch 000/100 | Train Loss: 1.82
# Epoch: 465/500 | Batch 000/100 | Train Loss: 1.45
# Epoch: 466/500 | Batch 000/100 | Train Loss: 1.62
# Epoch: 467/500 | Batch 000/100 | Train Loss: 1.80
# Epoch: 468/500 | Batch 000/100 | Train Loss: 1.47
# Epoch: 469/500 | Batch 000/100 | Train Loss: 1.61
# Epoch: 470/500 | Batch 000/100 | Train Loss: 1.78
# Epoch: 471/500 | Batch 000/100 | Train Loss: 1.47
# Epoch: 472/500 | Batch 000/100 | Train Loss: 1.61
# Epoch: 473/500 | Batch 000/100 | Train Loss: 1.79
# Epoch: 474/500 | Batch 000/100 | Train Loss: 1.47
# Epoch: 475/500 | Batch 000/100 | Train Loss: 1.60
# Epoch: 476/500 | Batch 000/100 | Train Loss: 1.79
# Epoch: 477/500 | Batch 000/100 | Train Loss: 1.47
# Epoch: 478/500 | Batch 000/100 | Train Loss: 1.59
# Epoch: 479/500 | Batch 000/100 | Train Loss: 1.79
# Epoch: 480/500 | Batch 000/100 | Train Loss: 1.48
# Epoch: 481/500 | Batch 000/100 | Train Loss: 1.60
# Epoch: 482/500 | Batch 000/100 | Train Loss: 1.79
# Epoch: 483/500 | Batch 000/100 | Train Loss: 1.49
# Epoch: 484/500 | Batch 000/100 | Train Loss: 1.60
# Epoch: 485/500 | Batch 000/100 | Train Loss: 1.78
# Epoch: 486/500 | Batch 000/100 | Train Loss: 1.49
# Epoch: 487/500 | Batch 000/100 | Train Loss: 1.60
# Epoch: 488/500 | Batch 000/100 | Train Loss: 1.78
# Epoch: 489/500 | Batch 000/100 | Train Loss: 1.50
# Epoch: 490/500 | Batch 000/100 | Train Loss: 1.61
# Epoch: 491/500 | Batch 000/100 | Train Loss: 1.77
# Epoch: 492/500 | Batch 000/100 | Train Loss: 1.51
# Epoch: 493/500 | Batch 000/100 | Train Loss: 1.62
# Epoch: 494/500 | Batch 000/100 | Train Loss: 1.77
# Epoch: 495/500 | Batch 000/100 | Train Loss: 1.51
# Epoch: 496/500 | Batch 000/100 | Train Loss: 1.63
# Epoch: 497/500 | Batch 000/100 | Train Loss: 1.76
# Epoch: 498/500 | Batch 000/100 | Train Loss: 1.52
# Epoch: 499/500 | Batch 000/100 | Train Loss: 1.65
# Epoch: 500/500 | Batch 000/100 | Train Loss: 1.72

# %%
model.eval()

# predecimos los valores del rango x segun el MLP
# Usamos los mismos valores de x generados para el seno
x_range = x

# Se pasan a un tensor normalizado usando las estadísticas correctas del seno
x_range_norm = (x_range - x_mean_sine) / x_std_sine
x_range_norm = torch.tensor(x_range_norm, dtype=torch.float32).unsqueeze(1) # Añadimos una dimensión para el modelo

# Se meten en el modelo
y_mlp_norm = model(x_range_norm)

# Ahora se desnormalizan para que estén en la misma escala usando las estadísticas correctas del seno
y_mlp_norm = y_mlp_norm.detach().numpy().astype(np.float64) # dejan de ser un tensor
y_mlp = y_mlp_norm * y_std_sine + y_mean_sine # desnormalizan

# Los datos originales
plt.scatter(x, y, label="Datos")

# Los datos predichos por el MLP
plt.plot(x_range, y_mlp, label="MLP", color='orange')

plt.xlabel("X")
plt.ylabel("y")
plt.legend()

plt.show()

# %% [markdown]
# ### 03. Ejercicio 3
#
# Regresión con datos de felicidad
#
# Se analizan unos datos obtenido de Kaggle.com sobre la encuesta de felicidad de 2021: [enlace](https://https://www.kaggle.com/datasets/ajaypalsinghlo/world-happiness-report-2021)
#
# Una vez limpiados y preparados la base de datos consta de 9 variables predictoras y una variable criterio:
#
# **Criterio**: Life.Ladder.
#
# **Predictoras**: year, Log.GDP.per.capita, Social.support, Healthy.life.expectancy.at.birth, Freedom.to.make.life.choices, Generosity, Perceptions.of.corruption, Positive.affect, Negative.affect.

# %%
# Funciones para importar y preparar los datos

import pandas as pd
url = 'https://raw.githubusercontent.com/mcstllns/UNIR2024/main/data-happiness.csv'
data  = pd.read_csv(url)
print(data.keys())
data.head()

# El fichero tiene datos perdidos y hay que eliminar las filas
data = data.dropna()

# Creamos conjuntos X e y
x = data.drop('Life.Ladder', axis=1)
y = data['Life.Ladder']

print(X.head())
print(y.head())
# Out:
# Index(['year', 'Life.Ladder', 'Log.GDP.per.capita', 'Social.support',
#        'Healthy.life.expectancy.at.birth', 'Freedom.to.make.life.choices',
#        'Generosity', 'Perceptions.of.corruption', 'Positive.affect',
#        'Negative.affect'],
#       dtype='object')
#    year  Log.GDP.per.capita  Social.support  Healthy.life.expectancy.at.birth  \
# 0  2008               7.370           0.451                             50.80
# 1  2009               7.540           0.552                             51.20
# 2  2010               7.647           0.539                             51.60
# 3  2011               7.620           0.521                             51.92
# 4  2012               7.705           0.521                             52.24
#
#    Freedom.to.make.life.choices  Generosity  Perceptions.of.corruption  \
# 0                         0.718       0.168                      0.882
# 1                         0.679       0.190                      0.850
# 2                         0.600       0.121                      0.707
# 3                         0.496       0.162                      0.731
# 4                         0.531       0.236                      0.776
#
#    Positive.affect  Negative.affect
# 0            0.518            0.258
# 1            0.584            0.237
# 2            0.618            0.275
# 3            0.611            0.267
# 4            0.710            0.268
# 0    3.724
# 1    4.402
# 2    4.758
# 3    3.832
# 4    3.783
# Name: Life.Ladder, dtype: float64

# %%
# preparamos los datos

from torch.utils.data import TensorDataset, DataLoader

# Normalizamos X e y
x_mean, x_std = x.mean(), x.std()
y_mean, y_std = y.mean(), y.std()

x_norm = (x - x_mean) / x_std
y_norm = (y - y_mean) / y_std

# Pasamos las variables a tensores
# Ojo, como son dataframes de pandas la sintaxis es un poco diferente

tensor_x = torch.from_numpy(x_norm.values).float()
tensor_y = torch.from_numpy(y_norm.values).float()

# Creamos el dataset y el dataloader
my_dataset = TensorDataset(tensor_x,tensor_y) # create your datset
my_dataloader = DataLoader(my_dataset) # create your dataloader

# %%
print(tensor_x.shape)
print(tensor_y.shape)
# Out:
# torch.Size([1708, 9])
# torch.Size([1708])

# %% [markdown]
# Ahora ya se puede calcular la red
#
# Ojo: NO intentes hacer un plot de X, y porque ahora X tiene 9 variables
#
# El mejor modelo calculado con estadística convencional (modelo lineal) da un **MSE de 0.235**
#
# **Supera el MSE de la regresión múltiple**

# %%
# Clase con el modelo
class MLP3(torch.nn.Module):
    def __init__(self, x_nvars):
        super().__init__()

        self.layers = torch.nn.Sequential(

            # Hidden Layer 1
            torch.nn.Linear(x_nvars, 20),
            torch.nn.ReLU(),

            # Hidden Layer 2
            torch.nn.Linear(20, 20),
            torch.nn.ReLU(),

            # Hidden Layer 3
            torch.nn.Linear(20, 20),
            torch.nn.ReLU(),

            # Hidden Layer 4
            torch.nn.Linear(20, 1),
            torch.nn.ReLU(),


            # output layer
            torch.nn.Linear(1, 1),
        )

    def forward(self, x):
        output = self.layers(x)
        return output

# %%
# Fijamos la semilla
torch.manual_seed(1)

# Creamos el modelo MLP con el número correcto de variables de entrada
model = MLP3(x_nvars=x.shape[1])

# Definimos la función loss
loss_fn = torch.nn.MSELoss()

# Elegimos el optimizador
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# Fijamos el número de épocas o iteraciones
num_epochs = 250

loss_history = []

for epoch in range(num_epochs):
    model = model.train()

    for batch_idx, (features, targets) in enumerate(my_dataloader):

        output = model(features)
        loss = loss_fn(output, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if not batch_idx % 100:
            print(
                f"Epoch: {epoch+1:03d}/{num_epochs:03d}"

                f" | Batch {batch_idx:03d}/{len(my_dataloader):03d}"
                f" | Train Loss: {loss.item():.2f}"
            )

    loss_history.append(loss.item())

print(f"Final Loss: {loss_history[-1]:.4f}")
# Out:
# Epoch: 001/250 | Batch 000/1708 | Train Loss: 0.35
# Epoch: 001/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 001/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 001/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 001/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 001/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 001/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 001/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 001/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 001/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 001/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 001/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 001/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 001/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 001/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 001/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 001/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 001/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 002/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 002/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 002/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 002/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 002/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 002/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 002/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 002/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 002/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 002/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 002/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 002/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 002/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 002/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 002/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 002/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 002/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 002/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 003/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 003/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 003/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 003/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 003/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 003/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 003/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 003/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 003/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 003/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 003/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 003/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 003/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 003/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 003/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 003/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 003/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 003/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 004/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 004/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 004/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 004/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 004/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 004/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 004/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 004/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 004/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 004/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 004/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 004/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 004/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 004/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 004/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 004/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 004/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 004/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 005/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 005/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 005/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 005/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 005/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 005/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 005/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 005/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 005/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 005/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 005/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 005/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 005/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 005/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 005/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 005/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 005/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 005/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 006/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 006/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 006/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 006/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 006/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 006/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 006/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 006/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 006/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 006/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 006/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 006/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 006/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 006/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 006/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 006/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 006/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 006/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 007/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 007/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 007/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 007/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 007/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 007/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 007/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 007/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 007/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 007/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 007/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 007/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 007/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 007/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 007/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 007/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 007/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 007/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 008/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 008/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 008/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 008/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 008/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 008/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 008/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 008/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 008/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 008/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 008/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 008/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 008/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 008/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 008/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 008/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 008/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 008/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 009/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 009/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 009/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 009/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 009/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 009/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 009/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 009/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 009/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 009/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 009/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 009/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 009/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 009/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 009/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 009/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 009/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 009/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 010/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 010/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 010/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 010/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 010/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 010/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 010/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 010/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 010/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 010/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 010/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 010/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 010/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 010/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 010/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 010/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 010/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 010/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 011/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 011/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 011/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 011/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 011/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 011/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 011/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 011/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 011/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 011/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 011/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 011/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 011/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 011/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 011/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 011/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: 011/250 | Batch 1600/1708 | Train Loss: 0.81
# Epoch: 011/250 | Batch 1700/1708 | Train Loss: 0.08
# Epoch: 012/250 | Batch 000/1708 | Train Loss: 0.01
# Epoch: 012/250 | Batch 100/1708 | Train Loss: 0.01
# Epoch: 012/250 | Batch 200/1708 | Train Loss: 0.35
# Epoch: 012/250 | Batch 300/1708 | Train Loss: 0.26
# Epoch: 012/250 | Batch 400/1708 | Train Loss: 0.03
# Epoch: 012/250 | Batch 500/1708 | Train Loss: 0.01
# Epoch: 012/250 | Batch 600/1708 | Train Loss: 0.07
# Epoch: 012/250 | Batch 700/1708 | Train Loss: 0.03
# Epoch: 012/250 | Batch 800/1708 | Train Loss: 0.84
# Epoch: 012/250 | Batch 900/1708 | Train Loss: 0.61
# Epoch: 012/250 | Batch 1000/1708 | Train Loss: 0.06
# Epoch: 012/250 | Batch 1100/1708 | Train Loss: 0.00
# Epoch: 012/250 | Batch 1200/1708 | Train Loss: 0.19
# Epoch: 012/250 | Batch 1300/1708 | Train Loss: 1.34
# Epoch: 012/250 | Batch 1400/1708 | Train Loss: 0.03
# Epoch: 012/250 | Batch 1500/1708 | Train Loss: 0.10
# Epoch: