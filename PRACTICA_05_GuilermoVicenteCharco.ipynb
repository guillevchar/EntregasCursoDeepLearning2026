# %% [markdown]
# <a href="https://colab.research.google.com/github/guillevchar/EntregasCursoDeepLearning2026/blob/main/PRACTICA_05_Ajuste_de_la_red.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="darkorange" size="10"><b>05. Ajuste de la red</b></font>
#
# Miguel A. Castellanos

# %% [markdown]
# # Estocástico, Batch y mini-batch
#
# Esto define si queremos un aprendizaje estocástico (actualización cada sujeto), por batch (actualización con el promedio de todos los sujetos) o por mini-batch (actualización por lotes de sujetos).
#
# Se determina simplemente usando la función DataLoader

# %%
dataloader = DataLoader(dataset) # estocastico
dataloader = DataLoader(dataset, batch_size=10, shuffle=True)  # mini-batch
dataloader = DataLoader(dataset, batch_size=len(my_dataset), shuffle=True) # batch completo

# %% [markdown]
# # Optimizadores
#
# ## SGD
#
#
# ```python
# optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=1e-4, nesterov=True)
# ```
#
# Siendo:
# - lr: Learning rate
# - momentum: Beta de momentum
# - weight_decay: el lambda2 de la Regularización L2
# - nesterov: Si está en True se activa la aceleración de nesterov
#
# ### Aceleración de Nesterov
# Cuando activas nesterov=True, el optimizador ajusta el cálculo del momentum para "mirar hacia adelante" antes de actualizar los pesos. Esto puede hacer que el entrenamiento sea más estable y rápido. Requiere que el momentum sea mayor que 0 (momentum > 0), de lo contrario, no tiene efecto.
#
# SGD hará aprendizaje estocástico si no definimos mini-batch. Si hacemos n=n1 o n=N hará mini-batchs o batch
#
# Básico y funciona bien. Muy sensible al Learning Rate.
#
#
# ## RMSprop
#
# ```python
# optimizer = optim.RMSprop(model.parameters(), lr=0.01, alpha=0.99, eps=1e-8, weight_decay=0, momentum=0.9)
# ```
# - lr:	Tasa de aprendizaje. Controla el tamaño de los pasos en la actualización de pesos.
# - alpha:	Factor de suavizado (0.99 por defecto). Controla cuánto contribuyen los gradientes pasados a la media móvil. Es lo que hemos llamado Beta en teoría
# - eps:	Término de estabilidad. Evita divisiones por cero (típicamente un valor muy muy pequeño, 1e-8). Es l oque hemos llamado epsilon en teoría.
# - weight_decay:	Regularización L2. Similar a la regularización en SGD, evita sobreajuste.
# - momentum:	Añade momento (por defecto 0). Se puede usar para mejorar convergencia.
# - centered:	Si es True, usa una media móvil del gradiente para normalizar mejor. No se usa mucho.
#
# Funciona bien en problemas longitudinales como redes recurrentes (RNNs).
# No siempre converge a la mejor solución (a veces encuentra mínimos locales).
# Menos robusto en redes muy profundas comparado con Adam.
#
#
# ## Adam
#
# ```python
# optimizer = optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-4)
# ```
#
# - lr:	Tasa de aprendizaje (0.001 por defecto).
# - betas:	Factores de decaimiento para momentum beta1 (0.9) y el segundo beta2 controla controla el beta del RMSProp
# - eps:	Término de estabilidad (1e-8). Evita divisiones por cero.
# - weight_decay:	Regularización L2 (por defecto 0)
#
# Es el que mejor funciona porque combina todo lo anterior. Requiere mas memoria que los anteriores y más cálculo. Hay que elegir sabiamente las betas para que vaya bien.

# %% [markdown]
# # Inicializacion de parametros
#
# Por defecto utiliza la siguiente inicialización y funciona muy bien, la verdad.
#
#
# | Capa | Inicialización por defecto |
# |------|----------------------------|
# |nn.Linear |	Uniforme en [-√k, √k], donde k = 1/in_features|
# | nn.Conv2d	| Uniforme en [-√k, √k], donde k = 1/in_features|
# | nn.BatchNorm	| pesos = 1, sesgos = 0 |
#
# Si se quiere utilizar las inicializaciones de Xavier, He y LeCun puede hacerse lo siguiente:

# %%
import torch
import torch.nn as nn
import torch.nn.init as init

class MLP(nn.Module):
    def __init__(self, X_nvars):
        super().__init__()

        self.layers = torch.nn.Sequential(

            # Hidden Layer 1
            torch.nn.Linear(X_nvars, 1), # Hacemos el sumatorio
            torch.nn.ReLU(),              # Aplicamos la función de activacion

            # output layer
            torch.nn.Linear(1, 1),
        )

        # Aqui es donde hacemos las incializaciones
        for layer in self.layers:
          if isinstance(layer, nn.Linear):
            init.xavier_uniform_(layer.weight)# Si queremos xavier con uniforme
            # init.xavier_normal_(layer.weight) # Si queremos xavier con normal

            # init.kaiming_uniform_(layer.weight, nonlinearity='relu') # Si queremos He con uniforme
            # init.kaiming_normal_(layer.weight, nonlinearity='relu') # Si queremos He con normal

            # # LeCun normal
            # init.normal_(layer.weight, mean=0, std=(1.0 / torch.sqrt(torch.tensor(layer.weight.size(1), dtype=torch.float))))

            # # Inicialización LeCun uniforme (no hay una función directa, pero se puede hacer manualmente)
            # fan_in = layer.weight.size(1)  # Número de entradas
            # bound = 1 / torch.sqrt(torch.tensor(fan_in, dtype=torch.float))
            # init.uniform_(layer.weight, -bound, bound)

    def forward(self, x):
        output = self.layers(x)
        return output

# %% [markdown]
# # Crear conjuntos de train, dev y test
#
# Lo primero, hay que tener en cuenta estas dos funciones:
#
# ```python
# model.train()
# model.eval()
# ```
#
# Ponen al modelo en modo entrenamiento o de evaluación y tiene efecto sobre algunas cosas del funcionamiento de la red, por ejemplo si se hacen o no los dropout, si se calcula el gradiente, etc.
#
# La división entre los conjuntos de datos se puede hacer cómo quieras, hay múltiples funciones para ello. Pytorch incorpora el random_split

# %%
import numpy as np
from torch.utils.data import TensorDataset, DataLoader, random_split

X = torch.randn(1000, 10)
y = torch.randint(0, 2, (1000,))  # Clasificación binaria

dataset = TensorDataset(X, y) # create your datset

# Definir tamaños de cada conjunto
train_size = int(0.8 * len(dataset))  # 80% para entrenamiento
dev_size = int(0.1 * len(dataset))  # 10% para validación
test_size = len(dataset) - train_size - dev_size  # 10% para prueba

# Dividir aleatoriamente
train_dataset, dev_dataset, test_dataset = random_split(dataset, [train_size, dev_size, test_size])

# Crear dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(dev_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

# %% [markdown]
# # Dropout
#
# Simplemente se introduce una capa de dropout después de la activación. El parámetro p define la cantidad de datos que queremos perder.
#
# - Si lo aplicamos antes de la activación, algunas neuronas pueden ser eliminadas antes de calcular su valor útil, perdiendo información antes de que sea procesada correctamente.
# - Aplicarlo después de la activación asegura que cada neurona ya tiene su contribución calculada antes de ser descartada temporalmente.

# %%
# dropout_p es la probabilidad de apagar una neurona (50%)
dropout_p = 0.5

class MLP(nn.Module):
    def __init__(self, input_size, hidden_size_1, hidden_size_2, output_size, dropout_p):
        super(MLP, self).__init__()

        self.model = nn.Sequential(
            # Capa de entrada a capa oculta 1
            nn.Linear(input_size, hidden_size_1),
            nn.ReLU(),
            nn.Dropout(p=dropout_p),  # Dropout después de la capa oculta 1

            # Capa oculta 1 a capa oculta 2
            nn.Linear(hidden_size_1, hidden_size_2),
            nn.ReLU(),
            nn.Dropout(p=dropout_p),  # Dropout después de la capa oculta 2

            # Capa oculta 2 a capa de salida
            nn.Linear(hidden_size_2, output_size),
            nn.Sigmoid()  # Para clasificación binaria, puedes usar softmax para clasificación múltiple
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# # Batch-normalization
#
# Batch Normalization es una técnica para normalizar (media = 0 y sd = 1) las activaciones de cada capa en mini-batches. Esto ayuda a acelerar el entrenamiento y a estabilizar la red. En PyTorch, puedes usar torch.nn.BatchNorm1d, BatchNorm2d, o BatchNorm3d, dependiendo de la dimensión de los datos que estés manejando.
#
#
# Ademas, la función BatchNorm de pytorch introduce dos nuevos parámetros:
#
# - β (bias): permite un desplazamiento en la media.
# - γ (scale factor): escala la distribución normalizada.
#
# Es decir, se le puede decir que en vez de acabar en (0,1) se reescale a y (β,γ). Esto permite que la red aprenda si necesita reescalar o desplazar los valores.

# %%
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size_1, hidden_size_2, output_size):
        super(MLP, self).__init__()

        self.model = nn.Sequential(
            # Capa de entrada a capa oculta 1
            nn.Linear(input_size, hidden_size_1),
            nn.BatchNorm1d(hidden_size_1),  # Normalización después de la capa 1
            nn.ReLU(),

            # Capa oculta 1 a capa oculta 2
            nn.Linear(hidden_size_1, hidden_size_2),
            nn.BatchNorm1d(hidden_size_2),  # Normalización después de la capa 2
            nn.ReLU(),

            # Capa oculta 2 a capa de salida
            nn.Linear(hidden_size_2, output_size),
            nn.Sigmoid()  # Para clasificación binaria
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# # Regularizaciones L1 y L2
#
# Lo más eficiente es usar L2 con el weight dacay de los optimizadores, pero si quieres programarla a pelo, o programar una elasticNet, puedes hacerlo:

# %%
# Se define ElasticNet
# Si haces l1_lambda o l2_lambda = 0 ese parámetro no influye
def l1_l2_regularization(model, l1_lambda, l2_lambda):
    l1_norm = sum(p.abs().sum() for p in model.parameters())  # L1
    l2_norm = sum(p.pow(2).sum() for p in model.parameters())  # L2
    return l1_lambda * l1_norm + l2_lambda * l2_norm

for epoch in range(num_epochs):

    model.train()
    for batch_idx, (features, targets) in enumerate(my_dataloader):

        # forward
        output = model(features)
        loss = loss_fn(output, targets)

        # La regularización
        reg_loss = l1_l2_regularization(model, l1_lambda, l2_lambda)
        total_loss = loss + reg_loss

        # backward
        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

# %% [markdown]
# # Usar la GPU
#
# Lo primero es crear un entorno de ejecución con una GPU
#
# Conectar -> Cambiar tipo de entorno de ejecución
#
# Y elegir GPU-T4

# %%
# Comprobamos si tenemos GPU
import torch
print(torch.cuda.is_available())  # Salida: True si hay una GPU disponible

# %%
# Si hay cuda indicamos que la GPU va a ser nuestro dispositivo de calculo, si no, la CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)

# %%
# Si tentemos cuda ponemos imprimir informacion
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')

# %%
# Esta función nos dice cosas de la Tarjeta grafica

if device.type == 'cuda':
  # !nvidia-smi

# %%
# Como lanzar un MLP sobre la GPU

# Lo primero es pasar todos los tensores a la GPU

# Dependiendo de la cantidad de memoria se recomiendan dos opciones:
# A. Pasamos todos los datos a la GPU desde el principio (si tenemos mucha Vram)

X, y = X.to(device), y.to(device)

# DataLoader sin necesidad de mover lotes a GPU
dataloader = DataLoader(TensorDataset(X, y), batch_size=32, shuffle=True)

# B. Vamos pasando los mini-batch según los vayamos usando
for epoch in range(5):
    for x_batch, y_batch in dataloader:

        # Mover solo el batch actual a GPU
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)


# Lo segundo ejecutar el modelo sobre la GPU
model = MLP().to(device)

# Y el resto del código sería igual que en otras ocasiones

# %% [markdown]
# # Búsqueda de hiper-parámetros con Optuna
#
# Vamos a partir de un MLP que ya vimos en la PRACTICA 04. Una red para clasificación binaria

# %%
# !pip install torcheval
# !pip install optuna

# %%
# Creamos unos datos

import torch
import torch.nn as nn
import torch.optim as optim
import optuna
import torcheval
from torch.utils.data import DataLoader, TensorDataset
from torcheval.metrics import BinaryAccuracy

X = torch.randn(1000, 10)
y = torch.randint(0, 2, (1000,))  # Clasificación binaria

train_dataset = TensorDataset(X, y)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
# Se define el MLP

class MLP(torch.nn.Module):
    def __init__(self, num_features):
        super().__init__()

        self.all_layers = torch.nn.Sequential(

            # 1st hidden layer
            torch.nn.Linear(num_features, 25),
            torch.nn.ReLU(),

            # output layer
            torch.nn.Linear(25, 1),
            # torch.nn.Sigmoid() # ver comentario 1

        )

    def forward(self, x):
        output = self.all_layers(x)
        return output.flatten()

# %%
# Se define Optuna

def objective(trial):

    # Aqui es donde se especifican los parametros que vamos a optimizar
    # Vamos a optimizar solo el lr del optimizador
    learning_rate = trial.suggest_loguniform("learning_rate", 0.001, 0.01)

    # Crear modelo con los hiperparámetros sugeridos
    model = MLP(num_features = 10)
    loss_fn = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    accuracy = BinaryAccuracy()

    model.train()
    # Entrenamiento simple
    for epoch in range(5):
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            output = model(X_batch)
            loss = loss_fn(output, y_batch.float())
            loss.backward()
            optimizer.step()

    # Evaluar precisión
    model.eval()
    for X_batch, y_batch in train_loader:
        output = model(X_batch)
        accuracy.update(output, y_batch)

    return accuracy.compute()  # Optuna intentará maximizar esto

# %%
study = optuna.create_study(direction="maximize")  # Buscamos maximizar la precisión
study.optimize(objective, n_trials=20)  # Probar 20 combinaciones

# 🔹 Mostrar los mejores hiperparámetros encontrados
print("Mejores hiperparámetros:", study.best_params)

# %%
optuna.visualization.matplotlib.plot_param_importances(study)

# %%
optuna.visualization.matplotlib.plot_optimization_history(study)

# %% [markdown]
# ### Ejercicio
#
# Para esta práctica vamos a utilizar el conjunto de datos MNIST que consiste en imágenes de números del 0 al 9 escritas a mano y digitalizadas. Una descripción del fichero la puedes encontrar en la [wikipedia](https://en.wikipedia.org/wiki/MNIST_database).
#
# Los datos están ya almacenados en pytorch, con lo que con una única función los podemos cargar y, además, están ya divididos en dos conjuntos de datos, un de entrenamiento con 60000 imágenes y otro de test con 10000 imágenes.
#
# El objetivo de la red es ser capaz de identificar correctamente el número y eso es equivalente a clasificar correctamente cada imagen.
#
# Los datos de entrada son imágenes en escala de grises, una matriz bidimensional de 28 x 28 en la que cada pixel va de 0 a 255. La mejor manera de trabajar con imágenes es a través de redes convolucionales pero todavía no las hemos estudiado así que vamos a vectorizar la imagen, es decir, concatenar las columnas una tras otra y formas un unico vector para cada imagen.
#
# Para procesar los datos vamos a construir un perceptron multicapa como los de los ejercicios anteriores pero ahora como entrada vamos a tener
#
# - **Para el train:** 60000 imágenes y sus etiquetas
# - **Para el test:** 10000 imágenes y sus etiquetas

# %%
# !pip install torcheval
# !pip install optuna
# Out:
# Collecting torcheval
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from torcheval) (4.15.0)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.48)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 12.6 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.8.0

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import optuna
import torcheval
from torch.utils.data import DataLoader, TensorDataset
from torcheval.metrics import BinaryAccuracy
import matplotlib.pyplot as plt

# %%
class Flatten(object):
    def __call__(self, tensor):
        # Aplanar la imagen a un vector de 784 píxeles
        return tensor.view(-1)


transform = transforms.Compose([
    transforms.ToTensor(),  # Convierte la imagen a tensor
    transforms.Normalize((0.5,), (0.5,)),  # Normalización
    transforms.Lambda(lambda x: x.view(-1)) # Aplanar las imágenes a un vector de 784 píxeles
    # Flatten()  # Aplanar las imágenes a un vector de 784 píxeles
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.2MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 519kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.64MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 12.5MB/s]

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 60000
# 10000

# %%
# Obtener una imagen y su etiqueta
image, label = train_dataset[0]  # Obtener la primera imagen del conjunto de entrenamiento

# Visualizar la imagen
plt.imshow(image.view(28,28), cmap='gray')  # .squeeze() elimina la dimensión de los canales (1,28,28 -> 28,28)
plt.title(f"Etiqueta: {label}")
plt.show()

# %% [markdown]
# ### Ejercicio 01
#
# Crea un MLP que realice una clasificación razonable, para ello utiliza las estrategias ***que consideres oportunas***.
#
# - Crear conjuntos de entrenamiento, dev y test
# - Ejecuta la red sobre una GPU
# - Buscar parámetros con Optuna
# - Usar regularizaciones
# - etc.

# %%
# Si hay cuda indicamos que la GPU va a ser nuestro dispositivo de calculo, si no, la CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
import torch
import torch.nn as nn
import torch.nn.init as init

dropout_p = 0.4 # Determinado por optuna

class MLP(nn.Module):
    def __init__(self, X_nvars, num_classes=10): # num_classes para MNIST
        super().__init__()

        self.layers = torch.nn.Sequential(
            # Capa oculta 1
            torch.nn.Linear(X_nvars, 128),
            torch.nn.ReLU(),
            nn.Dropout(p=dropout_p),

            # Capa oculta 2
            torch.nn.Linear(128, 64),
            torch.nn.ReLU(),
            nn.Dropout(p=dropout_p),

            # Capa de salida
            torch.nn.Linear(64, num_classes),
        )

        # Inicializaciones
        for layer in self.layers:
          if isinstance(layer, nn.Linear):
            init.kaiming_uniform_(layer.weight, nonlinearity='relu')

    def forward(self, x):
        output = self.layers(x)
        return output

# %%
from torch.utils.data import TensorDataset, DataLoader, random_split

# Dividir el train_dataset de MNIST en entrenamiento y validación
train_mnist_size = int(0.8 * len(train_dataset))  # 80% del MNIST original para entrenamiento
dev_mnist_size = len(train_dataset) - train_mnist_size  # 20% del MNIST original para validación

train_data_split, dev_data_split = random_split(train_dataset, [train_mnist_size, dev_mnist_size])

# Crear dataloaders para los conjuntos (los datos se moverán a la GPU en el bucle de entrenamiento)
train_loader = DataLoader(train_data_split, batch_size=32, shuffle=True)
valid_loader = DataLoader(dev_data_split, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32) # Usamos el test_dataset de MNIST ya cargado

# %%
import torch.optim as optim

# Instanciar el modelo, asumiendo 784 features de entrada para MNIST
model = MLP(X_nvars=784).to(device) # Instanciamos el modelo y lo movemos a la GPU
optimizer = optim.Adam(model.parameters(), lr=0.0008, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-4)

# El learning rate ha sido determinado por optuna

# %%
from torcheval.metrics import MulticlassAccuracy

# Parámetros de entrenamiento
num_epochs = 100
l1_lambda = 0.0001
l2_lambda = 0.0001
loss_fn = nn.CrossEntropyLoss()

def l1_l2_regularization(model, l1_lambda, l2_lambda):
    l1_norm = sum(p.abs().sum() for p in model.parameters())
    l2_norm = sum(p.pow(2).sum() for p in model.parameters())
    return l1_lambda * l1_norm + l2_lambda * l2_norm

# Inicializamos la métrica
metric = MulticlassAccuracy(num_classes=10, device=device)

print(f"Empezando entrenamiento en: {device}")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    metric.reset() # Reiniciamos la métrica en cada época

    for batch_idx, (features, targets) in enumerate(train_loader):
        # Mover a GPU
        features, targets = features.to(device), targets.to(device)

        # Forward
        output = model(features)
        loss = loss_fn(output, targets)

        # Regularización
        reg_loss = l1_l2_regularization(model, l1_lambda, l2_lambda)
        batch_total_loss = loss + reg_loss

        # Backward
        optimizer.zero_grad()
        batch_total_loss.backward()
        optimizer.step()

        # Actualizar métrica y pérdida
        total_loss += batch_total_loss.item()
        metric.update(output, targets)

    # Calculamos los resultados finales de la época
    avg_loss = total_loss / len(train_loader)
    epoch_acc = metric.compute()

    print(f"Época [{epoch+1}/{num_epochs}] - Loss: {avg_loss:.4f} - Accuracy: {epoch_acc:.4f}")

print("Entrenamiento finalizado.")
# Out:
# Empezando entrenamiento en: cuda
# Época [1/100] - Loss: 0.4827 - Accuracy: 0.9188
# Época [2/100] - Loss: 0.4811 - Accuracy: 0.9194
# Época [3/100] - Loss: 0.4798 - Accuracy: 0.9182
# Época [4/100] - Loss: 0.4861 - Accuracy: 0.9168
# Época [5/100] - Loss: 0.4818 - Accuracy: 0.9180
# Época [6/100] - Loss: 0.4798 - Accuracy: 0.9191
# Época [7/100] - Loss: 0.4804 - Accuracy: 0.9181
# Época [8/100] - Loss: 0.4755 - Accuracy: 0.9205
# Época [9/100] - Loss: 0.4854 - Accuracy: 0.9182
# Época [10/100] - Loss: 0.4773 - Accuracy: 0.9210
# Época [11/100] - Loss: 0.4795 - Accuracy: 0.9186
# Época [12/100] - Loss: 0.4756 - Accuracy: 0.9198
# Época [13/100] - Loss: 0.4770 - Accuracy: 0.9184
# Época [14/100] - Loss: 0.4738 - Accuracy: 0.9200
# Época [15/100] - Loss: 0.4785 - Accuracy: 0.9193
# Época [16/100] - Loss: 0.4774 - Accuracy: 0.9203
# Época [17/100] - Loss: 0.4794 - Accuracy: 0.9199
# Época [18/100] - Loss: 0.4817 - Accuracy: 0.9174
# Época [19/100] - Loss: 0.4808 - Accuracy: 0.9180
# Época [20/100] - Loss: 0.4750 - Accuracy: 0.9205
# Época [21/100] - Loss: 0.4887 - Accuracy: 0.9174
# Época [22/100] - Loss: 0.4796 - Accuracy: 0.9189
# Época [23/100] - Loss: 0.4764 - Accuracy: 0.9200
# Época [24/100] - Loss: 0.4779 - Accuracy: 0.9199
# Época [25/100] - Loss: 0.4735 - Accuracy: 0.9200
# Época [26/100] - Loss: 0.4750 - Accuracy: 0.9203
# Época [27/100] - Loss: 0.4753 - Accuracy: 0.9208
# Época [28/100] - Loss: 0.4791 - Accuracy: 0.9200
# Época [29/100] - Loss: 0.4768 - Accuracy: 0.9192
# Época [30/100] - Loss: 0.4783 - Accuracy: 0.9198
# Época [31/100] - Loss: 0.4854 - Accuracy: 0.9183
# Época [32/100] - Loss: 0.4741 - Accuracy: 0.9213
# Época [33/100] - Loss: 0.4732 - Accuracy: 0.9207
# Época [34/100] - Loss: 0.4759 - Accuracy: 0.9203
# Época [35/100] - Loss: 0.4791 - Accuracy: 0.9198
# Época [36/100] - Loss: 0.4743 - Accuracy: 0.9209
# Época [37/100] - Loss: 0.4774 - Accuracy: 0.9197
# Época [38/100] - Loss: 0.4744 - Accuracy: 0.9204
# Época [39/100] - Loss: 0.4715 - Accuracy: 0.9219
# Época [40/100] - Loss: 0.4776 - Accuracy: 0.9207
# Época [41/100] - Loss: 0.4816 - Accuracy: 0.9192
# Época [42/100] - Loss: 0.4739 - Accuracy: 0.9211
# Época [43/100] - Loss: 0.4740 - Accuracy: 0.9210
# Época [44/100] - Loss: 0.4746 - Accuracy: 0.9204
# Época [45/100] - Loss: 0.4798 - Accuracy: 0.9198
# Época [46/100] - Loss: 0.4716 - Accuracy: 0.9223
# Época [47/100] - Loss: 0.4797 - Accuracy: 0.9200
# Época [48/100] - Loss: 0.4788 - Accuracy: 0.9204
# Época [49/100] - Loss: 0.4774 - Accuracy: 0.9196
# Época [50/100] - Loss: 0.4776 - Accuracy: 0.9199
# Época [51/100] - Loss: 0.4808 - Accuracy: 0.9187
# Época [52/100] - Loss: 0.4786 - Accuracy: 0.9202
# Época [53/100] - Loss: 0.4712 - Accuracy: 0.9214
# Época [54/100] - Loss: 0.4774 - Accuracy: 0.9191
# Época [55/100] - Loss: 0.4733 - Accuracy: 0.9229
# Época [56/100] - Loss: 0.4758 - Accuracy: 0.9218
# Época [57/100] - Loss: 0.4777 - Accuracy: 0.9197
# Época [58/100] - Loss: 0.4803 - Accuracy: 0.9175
# Época [59/100] - Loss: 0.4846 - Accuracy: 0.9183
# Época [60/100] - Loss: 0.4727 - Accuracy: 0.9216
# Época [61/100] - Loss: 0.4751 - Accuracy: 0.9209
# Época [62/100] - Loss: 0.4735 - Accuracy: 0.9218
# Época [63/100] - Loss: 0.4788 - Accuracy: 0.9201
# Época [64/100] - Loss: 0.4694 - Accuracy: 0.9223
# Época [65/100] - Loss: 0.4814 - Accuracy: 0.9196
# Época [66/100] - Loss: 0.4717 - Accuracy: 0.9209
# Época [67/100] - Loss: 0.4732 - Accuracy: 0.9211
# Época [68/100] - Loss: 0.4765 - Accuracy: 0.9211
# Época [69/100] - Loss: 0.4734 - Accuracy: 0.9200
# Época [70/100] - Loss: 0.4767 - Accuracy: 0.9200
# Época [71/100] - Loss: 0.4690 - Accuracy: 0.9226
# Época [72/100] - Loss: 0.4762 - Accuracy: 0.9216
# Época [73/100] - Loss: 0.4792 - Accuracy: 0.9194
# Época [74/100] - Loss: 0.4719 - Accuracy: 0.9203
# Época [75/100] - Loss: 0.4752 - Accuracy: 0.9204
# Época [76/100] - Loss: 0.4728 - Accuracy: 0.9220
# Época [77/100] - Loss: 0.4749 - Accuracy: 0.9202
# Época [78/100] - Loss: 0.4738 - Accuracy: 0.9229
# Época [79/100] - Loss: 0.4778 - Accuracy: 0.9205
# Época [80/100] - Loss: 0.4788 - Accuracy: 0.9192
# Época [81/100] - Loss: 0.4731 - Accuracy: 0.9226
# Época [82/100] - Loss: 0.4767 - Accuracy: 0.9206
# Época [83/100] - Loss: 0.4665 - Accuracy: 0.9240
# Época [84/100] - Loss: 0.4752 - Accuracy: 0.9206
# Época [85/100] - Loss: 0.4788 - Accuracy: 0.9189
# Época [86/100] - Loss: 0.4740 - Accuracy: 0.9219
# Época [87/100] - Loss: 0.4781 - Accuracy: 0.9198
# Época [88/100] - Loss: 0.4696 - Accuracy: 0.9225
# Época [89/100] - Loss: 0.4825 - Accuracy: 0.9191
# Época [90/100] - Loss: 0.4789 - Accuracy: 0.9204
# Época [91/100] - Loss: 0.4814 - Accuracy: 0.9187
# Época [92/100] - Loss: 0.4790 - Accuracy: 0.9191
# Época [93/100] - Loss: 0.4763 - Accuracy: 0.9202
# Época [94/100] - Loss: 0.4731 - Accuracy: 0.9212
# Época [95/100] - Loss: 0.4677 - Accuracy: 0.9231
# Época [96/100] - Loss: 0.4774 - Accuracy: 0.9204
# Época [97/100] - Loss: 0.4786 - Accuracy: 0.9190
# Época [98/100] - Loss: 0.4666 - Accuracy: 0.9237
# Época [99/100] - Loss: 0.4745 - Accuracy: 0.9202
# Época [100/100] - Loss: 0.4728 - Accuracy: 0.9219
# Entrenamiento finalizado.

# %%
import torch
import matplotlib.pyplot as plt

# 1. Seleccionar una imagen del test_dataset
image, true_label = test_dataset[5]

# 2. Preparar el modelo para evaluación
model.eval()

# 3. Realizar la predicción
with torch.no_grad():
    # Añadimos una dimensión de batch (1, 784) y movemos al dispositivo
    input_tensor = image.unsqueeze(0).to(device)

    # Obtenemos la salida del modelo
    outputs = model(input_tensor)

    # La clase predicha es la que tiene el valor más alto (índice del máximo)
    _, predicted = torch.max(outputs, 1)
    predicted_label = predicted.item()

# 4. Visualizar
plt.imshow(image.view(28,28), cmap='gray')
plt.title(f"Real: {true_label} | Predicción: {predicted_label}")
plt.axis('off')
plt.show()

# %%
from torcheval.metrics import MulticlassAccuracy

def objective(trial):
    # Hiperparámetros a optimizar
    lr = trial.suggest_float("learning_rate", 1e-4, 1e-2, log=True)
    dropout_val = trial.suggest_float("dropout_p", 0.1, 0.5)

    # Actualizamos el dropout global para que la clase MLP lo use (o podrías pasarle el parámetro al init)
    global dropout_p
    dropout_p = dropout_val

    # Crear modelo y moverlo a la GPU
    model_trial = MLP(X_nvars=784).to(device)
    loss_fn = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model_trial.parameters(), lr=lr)

    metric = MulticlassAccuracy(num_classes=10, device=device)

    # Entrenamiento rápido para Optuna
    model_trial.train()
    for epoch in range(3):
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            output = model_trial(X_batch)
            loss = loss_fn(output, y_batch)
            loss.backward()
            optimizer.step()

    # Evaluación con el conjunto de validación
    model_trial.eval()
    with torch.no_grad():
        for X_batch, y_batch in valid_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            output = model_trial(X_batch)
            metric.update(output, y_batch)

    return metric.compute().item()

# %%
import optuna

# Crear el estudio de Optuna
study = optuna.create_study(direction="maximize")  # Buscamos maximizar la precisión
study.optimize(objective, n_trials=20)  # Probar 20 combinaciones

# 🔹 Mostrar los mejores hiperparámetros encontrados
print("Mejores hiperparámetros:", study.best_params)
# Out:
# [I 2026-03-17 13:49:15,033] A new study created in memory with name: no-name-5dea40a4-fd47-42d8-8b26-1b30184046d4
# [I 2026-03-17 13:49:55,283] Trial 0 finished with value: 0.9424999952316284 and parameters: {'learning_rate': 0.00011405876960814422, 'dropout_p': 0.35642086130611295}. Best is trial 0 with value: 0.9424999952316284.
# [I 2026-03-17 13:50:33,801] Trial 1 finished with value: 0.9604166746139526 and parameters: {'learning_rate': 0.0007313778187909409, 'dropout_p': 0.20265272920321784}. Best is trial 1 with value: 0.9604166746139526.
# [I 2026-03-17 13:51:11,860] Trial 2 finished with value: 0.9503333568572998 and parameters: {'learning_rate': 0.0001187385507921096, 'dropout_p': 0.14090995874860443}. Best is trial 1 with value: 0.9604166746139526.
# [I 2026-03-17 13:51:49,989] Trial 3 finished with value: 0.940416693687439 and parameters: {'learning_rate': 0.00010589580209678659, 'dropout_p': 0.10000975919916733}. Best is trial 1 with value: 0.9604166746139526.
# [I 2026-03-17 13:52:27,798] Trial 4 finished with value: 0.9497500061988831 and parameters: {'learning_rate': 0.00024285123141462627, 'dropout_p': 0.431309538367882}. Best is trial 1 with value: 0.9604166746139526.
# [I 2026-03-17 13:53:05,625] Trial 5 finished with value: 0.9605833292007446 and parameters: {'learning_rate': 0.0004957660054680302, 'dropout_p': 0.2605025159583997}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:53:43,851] Trial 6 finished with value: 0.9512500166893005 and parameters: {'learning_rate': 0.0014714788950982974, 'dropout_p': 0.25329309843548153}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:54:23,161] Trial 7 finished with value: 0.9590833187103271 and parameters: {'learning_rate': 0.0006217315485775661, 'dropout_p': 0.3015450149776105}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:55:02,308] Trial 8 finished with value: 0.9572499990463257 and parameters: {'learning_rate': 0.00019768243177987476, 'dropout_p': 0.3861271444222014}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:55:42,240] Trial 9 finished with value: 0.9259999990463257 and parameters: {'learning_rate': 0.004616651870060613, 'dropout_p': 0.48362818314024947}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:56:21,532] Trial 10 finished with value: 0.9330000281333923 and parameters: {'learning_rate': 0.002464860380596267, 'dropout_p': 0.21414164170108235}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:56:59,422] Trial 11 finished with value: 0.9601666927337646 and parameters: {'learning_rate': 0.0005927192283166557, 'dropout_p': 0.19730049871359218}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:57:37,205] Trial 12 finished with value: 0.9545833468437195 and parameters: {'learning_rate': 0.0004960430535094163, 'dropout_p': 0.29678483857082966}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:58:14,706] Trial 13 finished with value: 0.9599999785423279 and parameters: {'learning_rate': 0.001233465545654196, 'dropout_p': 0.18819007953272432}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:58:52,239] Trial 14 finished with value: 0.9356666803359985 and parameters: {'learning_rate': 0.007529184828439023, 'dropout_p': 0.2625316189099059}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 13:59:29,875] Trial 15 finished with value: 0.9495833516120911 and parameters: {'learning_rate': 0.0003546419305575108, 'dropout_p': 0.15354587589013635}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 14:00:08,273] Trial 16 finished with value: 0.9496666789054871 and parameters: {'learning_rate': 0.0023636414314961284, 'dropout_p': 0.33017972671660595}. Best is trial 5 with value: 0.9605833292007446.
# [I 2026-03-17 14:00:46,826] Trial 17 finished with value: 0.9638333320617676 and parameters: {'learning_rate': 0.0007934289945646565, 'dropout_p': 0.2406253308646087}. Best is trial 17 with value: 0.9638333320617676.
# [I 2026-03-17 14:01:24,832] Trial 18 finished with value: 0.9577500224113464 and parameters: {'learning_rate': 0.00034591741185703497, 'dropout_p': 0.24846788405043888}. Best is trial 17 with value: 0.9638333320617676.
# [I 2026-03-17 14:02:02,735] Trial 19 finished with value: 0.9571666717529297 and parameters: {'learning_rate': 0.0010236438099329285, 'dropout_p': 0.39939453423064103}. Best is trial 17 with value: 0.9638333320617676.
# Mejores hiperparámetros: {'learning_rate': 0.0007934289945646565, 'dropout_p': 0.2406253308646087}

# %%
optuna.visualization.matplotlib.plot_param_importances(study)

# %%
optuna.visualization.matplotlib.plot_optimization_history(study)
